# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pprint import pprint
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import decode_predictions
# Out:
# 2022-11-18 11:50:01.139767: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
m = VGG16(weights='imagenet')
# Out:
# 2022-11-18 11:50:29.540297: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image = plt.imread('/Users/Varvara/Downloads/aquarium.jpg')
plt.imshow(image)

# %%
image = cv2.resize(image,(224,224),interpolation=cv2.INTER_CUBIC)
image = np.expand_dims(image, axis=0)
image.shape
# Out:
# (1, 224, 224, 3)

# %%
results = m.predict(image)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pprint(decode_predictions(results, 10))
# Out:
# [[('n09256479', 'coral_reef', 0.6792931),
#   ('n04209239', 'shower_curtain', 0.28370994),
#   ('n01910747', 'jellyfish', 0.010663985),
#   ('n04522168', 'vase', 0.00929209),
#   ('n10565667', 'scuba_diver', 0.0023434337),
#   ('n03598930', 'jigsaw_puzzle', 0.002098658),
#   ('n03930313', 'picket_fence', 0.0017282461),
#   ('n01950731', 'sea_slug', 0.0014669743),
#   ('n03944341', 'pinwheel', 0.0012431054),
#   ('n03388043', 'fountain', 0.00078019046)]]

# %%
# Create a prediction from the image slice
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions

model_mobilenet = MobileNetV2(weights='imagenet', include_top=True)

# %%
model_mobilenet.compile(optimizer='rmsprop', loss='categorical_crossentropy',
           metrics=['accuracy'])

# %%
predictions = model_mobilenet.predict(image)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
from pprint import pprint

pprint(decode_predictions(predictions, 10))
# Out:
# [[('n04209239', 'shower_curtain', 0.57541233),
#   ('n03938244', 'pillow', 0.1008062),
#   ('n03291819', 'envelope', 0.046442367),
#   ('n03485794', 'handkerchief', 0.04350477),
#   ('n02730930', 'apron', 0.03335585),
#   ('n02834397', 'bib', 0.0294475),
#   ('n04548362', 'wallet', 0.028852647),
#   ('n04026417', 'purse', 0.006356118),
#   ('n04589890', 'window_screen', 0.0056806942),
#   ('n15075141', 'toilet_tissue', 0.005649397)]]

# %%
image = cv2.resize(image,(224,224),interpolation=cv2.INTER_CUBIC)
image = np.expand_dims(image, axis=0)
image.shape

# %%
slice_fish = img_array[224:448, 224:448, :]
slice_fish = np.expand_dims(slice_fish, axis=0)  
slice_fish = slice_fish / 255.0 
slice_fish.shape, slice_fish.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 img_array = image.img_to_array(image)
#       3 slice_fish = img_array[224:448, 224:448, :]
#       4 slice_fish = np.expand_dims(slice_fish, axis=0)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'img_to_array'

# %%
predictions = model_mobilenet.predict(slice_fish)
pprint(decode_predictions(predictions, 10))
decode = decode_predictions(predictions, 10)
